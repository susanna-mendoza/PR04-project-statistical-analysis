# %% [markdown]
# # AIRBNB DATASET

# %%
import pandas as pd

# %%
df = pd.read_csv('airbnb.csv')

# %%
df.head()
# Out:
#       id                                             name  host_id  \
# 0  18674  Huge flat for 8 people close to Sagrada Familia    71615
# 1  23197  Forum DeLuxe 5 mins Walk  To CCIB Center & Sea★    90417
# 2  25786       NICE ROOM AVAILABLE IN THE HEART OF GRACIA   108310
# 3  31958                  Gaudi Attic 1, Friendly Rentals   136853
# 4  32471                  Gaudi Attic 2, Friendly Rentals   136853
#
#           host_name neighbourhood_group                       neighbourhood  \
# 0  Mireia And Maria            Eixample                  la Sagrada Família
# 1    Etain (Marnie)          Sant Martí               el Besòs i el Maresme
# 2             Pedro              Gràcia                   la Vila de Gràcia
# 3           Fidelio              Gràcia  el Camp d'en Grassot i Gràcia Nova
# 4           Fidelio              Gràcia  el Camp d'en Grassot i Gràcia Nova
#
#    latitude  longitude        room_type  price  minimum_nights  \
# ...

# %%
df.shape
# Out:
# (20981, 16)

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
df.id.duplicated().sum()
# Out:
# 0

# %% [markdown]
# >Since we don't have duplicates, by apartment ID we have a unique identification value per apartment.

# %%
df.drop(['latitude','longitude'], axis=1, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.host_id.value_counts().plot(kind='bar', figsize = (16, 12));

# %%
df.shape
# Out:
# (15861, 14)

# %% [markdown]
# ## Apartments x district

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.neighbourhood_group.value_counts().plot(kind='bar', figsize = (12, 8));

# %%
df['host_id'].hist()
# Out:
# <AxesSubplot:>

# %%
df.host_id.value_counts().plot(kind='bar', figsize = (12, 8));

# %%
df.describe()
# Out:
#                  id       host_id         price  minimum_nights  \
# count  1.586100e+04  1.586100e+04  15861.000000    15861.000000
# mean   2.171008e+07  9.237498e+07    131.609167        6.544480
# std    1.282214e+07  9.894710e+07    455.527415       16.653902
# min    1.867400e+04  3.073000e+03      8.000000        1.000000
# 25%    1.094119e+07  7.384171e+06     38.000000        1.000000
# 50%    2.223605e+07  4.367630e+07     60.000000        2.000000
# 75%    3.337212e+07  1.638183e+08    108.000000        3.000000
# max    4.230860e+07  3.360357e+08  15000.000000     1124.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       15861.000000       15861.000000                    15861.000000
# mean           47.470777           1.633311                       12.945968
# std            70.453089           1.642921                       27.632082
# min             1.000000           0.010000                        1.000000
# ...

# %%
host = df.'host_id'.value_counts(sort=True).tolist()

# %%
host

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
sns.heatmap(df.corr(), cmap='coolwarm', annot=True);

# %%
sns.regplot(data=df, x='id', y='number_of_reviews');

# %%
 sns.jointplot(x='id', y='number_of_reviews', data=df);

# %%
sns.boxplot(x='id', y='number_of_reviews', data=df)

# %%
 sns.jointplot(x='neighbourhood_group', y='room_type', data=df);

# %%
sns.regplot(data=df, x='neighbourhood_group', y='id');
