# %% [markdown]
# # DRINKS & MUSIC BARS BARCELONA

# %%
import pandas as pd

# %%
bars = pd.read_csv('music_drinks.csv')

# %%
bars.head()
# Out:
#    CODI_EQUIPAMENT         EQUIPAMENT SECCIO TIPUS_VIA NOM_CARRER  \
# 0        119161015          Bar Zelig      #         C      Carme
# 1        119161015          Bar Zelig      #         C      Carme
# 2        283174133  Bar La Confiteria      #         C   Sant Pau
# 3        283174133  Bar La Confiteria      #         C   Sant Pau
# 4        283174133  Bar La Confiteria      #         C   Sant Pau
#
#    NUM_CARRER_1  NUM_CARRER_2  CODI_BARRI NUM_BARRI  CODI_DISTRICTE  ...  \
# 0           116         116.0           1  el Raval               1  ...
# 1           116         116.0           1  el Raval               1  ...
# 2           128         128.0           1  el Raval               1  ...
# 3           128         128.0           1  el Raval               1  ...
# 4           128         128.0           1  el Raval               1  ...
#
#   HORARI_PERIODE_INICI  HORARI_PERIODE_FI  HORARI_DIES HORARI_HORES_INICI  \
# ...

# %%
bars.shape
# Out:
# (1436, 33)

# %%
bars.dtypes
# Out:
# CODI_EQUIPAMENT           int64
# EQUIPAMENT               object
# SECCIO                   object
# TIPUS_VIA                object
# NOM_CARRER               object
# NUM_CARRER_1              int64
# NUM_CARRER_2            float64
# CODI_BARRI                int64
# NUM_BARRI                object
# CODI_DISTRICTE            int64
# NOM_DISTRICTE            object
# CODI_POSTAL               int64
# CODI_POBLACIO             int64
# POBLACIO                 object
# LATITUD                 float64
# LONGITUD                float64
# X_ETRS89                float64
# Y_ETRS89                float64
# X_ED50                  float64
# Y_ED50                  float64
# TELEFON_NUM              object
# TELEFON_TIPUS            object
# TELEFON_INFO_COM         object
# HORARI_PERIODE_INICI     object
# HORARI_PERIODE_FI        object
# HORARI_DIES             float64
# HORARI_HORES_INICI       object
# HORARI_HORES_FI          object
# HORARI_OBSERVACIONS     float64
# ...

# %%
locals = bars.EQUIPAMENT.value_counts()

# %%
locals
# Out:
# Discoteca Barroko's          36
# Bar musical La Torre Rosa    32
# Bar La Confiteria            32
# Jamboree                     24
# Sidecar Factory Club         24
#                              ..
# Cocteleria Bloody Mary        2
# Bar musical Bendita Salsa     2
# Discoteca Wolf Barcelona      2
# Restaurant Nº 30              2
# Bar Musical Carita Bonita     2
# Name: EQUIPAMENT, Length: 359, dtype: int64

# %%
pd.DataFrame.drop_duplicates(bars)
# Out:
#       CODI_EQUIPAMENT         EQUIPAMENT SECCIO TIPUS_VIA  \
# 0           119161015          Bar Zelig      #         C
# 2           283174133  Bar La Confiteria      #         C
# 3           283174133  Bar La Confiteria      #         C
# 4           283174133  Bar La Confiteria      #         C
# 5           283174133  Bar La Confiteria      #         C
# ...               ...                ...    ...       ...
# 1431      99400637878     Espai ClubHaus      #        Av
# 1432      99400637878     Espai ClubHaus      #        Av
# 1433      99400637878     Espai ClubHaus      #        Av
# 1434      99400637878     Espai ClubHaus      #        Av
# 1435      99400637878     Espai ClubHaus      #        Av
#
#                   NOM_CARRER  NUM_CARRER_1  NUM_CARRER_2  CODI_BARRI  \
# 0                      Carme           116         116.0           1
# 2                   Sant Pau           128         128.0           1
# ...

# %%
bars.EQUIPAMENT.duplicated().sum()
# Out:
# 1077

# %% [markdown]
# > OMG, we have 1077 duplicated bars!!

# %%
bars.drop_duplicates('EQUIPAMENT', keep='first')
# Out:
#       CODI_EQUIPAMENT                                  EQUIPAMENT SECCIO  \
# 0           119161015                                   Bar Zelig      #
# 2           283174133                           Bar La Confiteria      #
# 34          321103526                         Bar Musical Síncopa      #
# 38          325120406                                Atlàntic Bar      #
# 44          333173100                                  Razzmatazz      #
# ...               ...                                         ...    ...
# 1420      99400504492  Sala de Festes La Paloma *En Rehabilitació      #
# 1422      99400628268                   L'Ex-Designer Project Bar      #
# 1424      99400628369                         Bar Musical Ruta 66      #
# 1426      99400629064                     Bar Musical Robadors 23      #
# 1428      99400637878                              Espai ClubHaus      #
#
#      TIPUS_VIA              NOM_CARRER  NUM_CARRER_1  NUM_CARRER_2  \
# ...

# %% [markdown]
# >Duplicated cleaned, 359 different bars.

# %%
bars.NOM_DISTRICTE .value_counts().plot(kind='bar', figsize = (12, 8))
# Out:
# <AxesSubplot:>
